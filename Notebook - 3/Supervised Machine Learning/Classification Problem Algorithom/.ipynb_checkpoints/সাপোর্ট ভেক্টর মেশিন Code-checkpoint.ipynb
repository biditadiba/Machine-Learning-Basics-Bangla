# %% [markdown]
# # Import the Relevant Libraries

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
dir(iris) #columns in iris dataset
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target #adding target column
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2  \
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df[df.target==0].head() #from 0 to 49 its target 0
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2  \
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df[df.target==1].head() #from 50 to 99 its target 1
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 50                7.0               3.2                4.7               1.4  \
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df[df.target==1].head() #from 100 to 149 its target 12
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 50                7.0               3.2                4.7               1.4  \
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df['flower_name'] =df.target.apply(lambda x: iris.target_names[x]) #adding flower_name column corresponding to target column
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2  \
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
import matplotlib.pyplot as plt
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'],color="green",marker='+')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'],color="blue",marker='.')

# %%
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.scatter(df0['petal length (cm)'], df0['petal width (cm)'],color="green",marker='+')
plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'],color="blue",marker='.')

# %% [markdown]
# # Train Using Support Vector Machine (SVM)

# %%
x = df.drop(['target','flower_name'], axis='columns')
y = df.target # y = for prediction , we need to predoct flower_name based on the length and width

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split as tts
xtrain,xtest,ytrain,ytest = tts(x,y,test_size=0.2,random_state=50) #dividing the data

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
model.predict([[4.8,3.0,1.5,0.3]])
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0])

# %%
pred = model.predict(xtest)
pred
# Out:
# array([1, 2, 0, 0, 2, 2, 2, 0, 0, 1, 0, 2, 0, 2, 1, 0, 1, 0, 1, 2, 2, 1,
#        0, 2, 1, 2, 1, 1, 1, 2])

# %%
from sklearn.metrics import r2_score
r2_score(ytest,pred)
# Out:
# 0.8888888888888888

# %% [markdown]
# # Using different types of Kernel

# %%
model = SVC(kernel = 'linear', random_state = 0)
model.fit(xtrain, ytrain)
ypred1 = model.predict(xtest)
ypred1
# Out:
# array([1, 2, 0, 0, 2, 2, 2, 0, 0, 1, 0, 2, 0, 2, 1, 0, 1, 0, 1, 2, 2, 1,
#        0, 2, 1, 2, 1, 1, 1, 2])

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred1)# ytest = actual value of y that is stored in data frame, ypred = predicted value of y corresponding to xtest
# Out:
# 0.8888888888888888

# %%
model = SVC(kernel = 'rbf', random_state = 0)
model.fit(xtrain, ytrain)
ypred2 = model.predict(xtest)
ypred2
# Out:
# array([1, 2, 0, 0, 2, 2, 2, 0, 0, 1, 0, 2, 0, 2, 1, 0, 1, 0, 1, 2, 2, 1,
#        0, 2, 1, 2, 1, 1, 1, 2])

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred2)
# Out:
# 0.8888888888888888

# %% [markdown]
# # Tune parameters

# %% [markdown]
# 1. Gamma<br>
# ![image.png](attachment:image.png)<br>
# ![image-2.png](attachment:image-2.png) <br>

# %%
model_g = SVC(gamma=10)
model_g.fit(xtrain, ytrain)
ypred = model.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.8888888888888888

# %%
model_g = SVC(gamma=0)
model_g.fit(xtrain, ytrain)
ypred = model.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.8888888888888888

# %% [markdown]
# 1. Regularization (C)<br>
# ![image.png](attachment:image.png) <br>

# %%
model_g = SVC(C=3)
model_g.fit(xtrain, ytrain)
ypred = model.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.8888888888888888

# %%
model_g = SVC(C=8)
model_g.fit(xtrain, ytrain)
ypred = model.predict(xtest)
r2_score(ytest,ypred)
# Out:
# 0.8888888888888888
